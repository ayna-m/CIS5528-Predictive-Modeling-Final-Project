# %% [markdown]
# # Preprocessing for clinical data
# Largely adapted from the [Multisurv model clinical preprocessing](https://github.com/luisvalesilva/multisurv/blob/master/data/preprocess_clinical.ipynb)

# %%
import pandas as pd 
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

# %%
gene_expression_data = 'data/data_mrna_illumina_microarray.txt'
cna_data = 'data/data_cna.txt'
clinical_data = 'data/data_clinical_patient.txt'

# %%
results_dir = Path('./results')
results_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### 1.1. Exploring data

# %%
gene_exp_df = pd.read_table(gene_expression_data, sep='\t')
gene_exp_df.shape
# Out:
# (20603, 1982)

# %%
gene_exp_df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id   MB-0362   MB-0346    MB-0386   MB-0574  \
# 0        RERE             473  8.676978  9.653589   9.033589  8.814855
# 1      RNF165          494470  6.075331  6.687887   5.910885  5.628740
# 2        PHF7           51533  5.838270  5.600876   6.030718  5.849428
# 3       CIDEA            1149  6.397503  5.246319  10.111816  6.116868
# 4       TENT2          167153  7.906217  8.267256   7.959291  9.206376
#
#     MB-0185   MB-0503   MB-0641   MB-0201  ...   MB-6192   MB-4820   MB-5527  \
# 0  8.736406  9.274265  9.286585  8.437347  ...  8.804947  9.991215  9.595923
# 1  6.392422  5.908698  6.206729  6.095592  ...  5.601472  7.103160  6.418987
# 2  5.542133  5.964661  5.783374  5.737572  ...  5.922894  6.181493  5.992153
# 3  5.184098  7.828171  8.744149  5.480091  ...  6.488136  5.612846  6.241160
# 4  8.162845  8.706646  8.518929  7.478413  ...  8.534527  8.203819  8.813103
#
#     MB-5167   MB-5465   MB-5453   MB-5471   MB-5127   MB-4313   MB-4823
# 0  9.637249  8.131637  9.606915  9.049296  8.858622  8.415867  9.902776
# 1  6.203370  9.101942  7.427494  6.850000  6.550450  6.831722  7.338318
# 2  6.230316  5.644587  5.927409  6.117095  5.936371  7.408960  5.875759
# 3  5.560488  5.611189  5.927031  6.374305  5.963092  9.181768  5.596873
# 4  8.612911  7.798269  8.520545  8.499637  9.320207  6.804085  8.436732
#
# [5 rows x 1982 columns]

# %%
cna_df = pd.read_table(cna_data, sep='\t')
cna_df.shape
# Out:
# (22544, 2175)

# %%
clinical_df = pd.read_table(clinical_data, sep='\t')
clinical_df.shape
# Out:
# (2513, 24)

# %%
clinical_df.head()
# Out:
#                           #Patient Identifier  Lymph nodes examined positive  \
# 0  #Identifier to uniquely specify a patient.  Number of lymphnodes positive
# 1                                     #STRING                         STRING
# 2                                          #1                              1
# 3                                  PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE
# 4                                     MB-0000                             10
#
#    Nottingham prognostic index    Cellularity   Chemotherapy   Cohort  \
# 0  Nottingham prognostic index  Tumor Content  Chemotherapy.  Cohort.
# 1                       NUMBER         STRING         STRING   STRING
# 2                            1              1              1        1
# 3                          NPI    CELLULARITY   CHEMOTHERAPY   COHORT
# 4                        6.044            NaN             NO        1
#
#    ER status measured by IHC  HER2 status measured by SNP6  Hormone Therapy  \
# 0  ER status measured by IHC  HER2 status measured by SNP6  Hormone Therapy
# 1                     STRING                        STRING           STRING
# 2                          1                             1                1
# 3                     ER_IHC                     HER2_SNP6  HORMONE_THERAPY
# 4                    Positve                       NEUTRAL              YES
#
#    Inferred Menopausal State  ...           Overall Survival Status  \
# 0  Inferred Menopausal State  ...  Overall patient survival status.
# 1                     STRING  ...                            STRING
# 2                          1  ...                                 1
# 3  INFERRED_MENOPAUSAL_STATE  ...                         OS_STATUS
# 4                       Post  ...                          0:LIVING
#
#    Pam50 + Claudin-low subtype  3-Gene classifier subtype  \
# 0  Pam50 + Claudin-low subtype  3-Gene classifier subtype
# 1                       STRING                     STRING
# 2                            1                          1
# 3              CLAUDIN_SUBTYPE                  THREEGENE
# 4                  claudin-low                  ER-/HER2-
#
#               Patient's Vital Status  \
# 0  The survival state of the person.
# 1                             STRING
# 2                                  1
# 3                       VITAL_STATUS
# 4                             Living
#
#                             Primary Tumor Laterality  Radio Therapy  \
# 0  For tumors in paired organs, designates the si...  Radio Therapy
# 1                                             STRING         STRING
# 2                                                  1              1
# 3                                         LATERALITY  RADIO_THERAPY
# 4                                              Right            YES
#
#                       Tumor Other Histologic Subtype  Type of Breast Surgery  \
# 0  Text to describe a tumor's histologic subtype ...  Type of Breast Surgery
# 1                                             STRING                  STRING
# 2                                                  1                       1
# 3                               HISTOLOGICAL_SUBTYPE          BREAST_SURGERY
# 4                                         Ductal/NST              MASTECTOMY
#
#                                  Relapse Free Status  \
# 0  Relapse Free Status (Recurred = cases where th...
# 1                                             STRING
# 2                                                  1
# 3                                         RFS_STATUS
# 4                                     0:Not Recurred
#
#                        Relapse Free Status (Months)
# 0  Time until last follow-up or relapse (in months)
# 1                                            NUMBER
# 2                                                 1
# 3                                        RFS_MONTHS
# 4                                            138.65
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 1.1. Dropping unnecessary rows and columns from clinical data

# %%
# Dropping unnecessary rows and columns
clinical_df = clinical_df.drop(clinical_df.index[:4]).reset_index() #headers
clinical_df = clinical_df.drop(clinical_df.columns[0],axis=1) #index column
clinical_df.head()
# Out:
#   #Patient Identifier Lymph nodes examined positive  \
# 0             MB-0000                            10
# 1             MB-0002                             0
# 2             MB-0005                             1
# 3             MB-0006                             3
# 4             MB-0008                             8
#
#   Nottingham prognostic index Cellularity Chemotherapy Cohort  \
# 0                       6.044         NaN           NO      1
# 1                        4.02        High           NO      1
# 2                        4.03        High          YES      1
# 3                        4.05    Moderate          YES      1
# 4                        6.08        High          YES      1
#
#   ER status measured by IHC HER2 status measured by SNP6 Hormone Therapy  \
# 0                   Positve                      NEUTRAL             YES
# 1                   Positve                      NEUTRAL             YES
# 2                   Positve                      NEUTRAL             YES
# 3                   Positve                      NEUTRAL             YES
# 4                   Positve                      NEUTRAL             YES
#
#   Inferred Menopausal State  ... Overall Survival Status  \
# 0                      Post  ...                0:LIVING
# 1                       Pre  ...                0:LIVING
# 2                       Pre  ...              1:DECEASED
# 3                       Pre  ...                0:LIVING
# 4                      Post  ...              1:DECEASED
#
#   Pam50 + Claudin-low subtype 3-Gene classifier subtype  \
# 0                 claudin-low                 ER-/HER2-
# 1                        LumA     ER+/HER2- High Prolif
# 2                        LumB                       NaN
# 3                        LumB                       NaN
# 4                        LumB     ER+/HER2- High Prolif
#
#   Patient's Vital Status Primary Tumor Laterality Radio Therapy  \
# 0                 Living                    Right           YES
# 1                 Living                    Right           YES
# 2        Died of Disease                    Right            NO
# 3                 Living                    Right           YES
# 4        Died of Disease                    Right           YES
#
#   Tumor Other Histologic Subtype Type of Breast Surgery Relapse Free Status  \
# 0                     Ductal/NST             MASTECTOMY      0:Not Recurred
# 1                     Ductal/NST      BREAST CONSERVING      0:Not Recurred
# 2                     Ductal/NST             MASTECTOMY          1:Recurred
# 3                          Mixed             MASTECTOMY      0:Not Recurred
# 4                          Mixed             MASTECTOMY          1:Recurred
#
#   Relapse Free Status (Months)
# 0                       138.65
# 1                        83.52
# 2                       151.28
# 3                       162.76
# 4                        18.55
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 1.2 Selecting patients that have all 3 data types: gene expression, CNA, clinical

# %%
gene_exp_patients = set(gene_exp_df.columns[2:])
cna_patients = set(cna_df.columns[2:])
clinical_patients = set(clinical_df['#Patient Identifier'])

common_patients = gene_exp_patients.intersection(cna_patients, clinical_patients)

gene_exp_columns_to_drop = [col for col in gene_exp_df.columns[2:] if col not in common_patients]
gene_exp_df = gene_exp_df.drop(columns=gene_exp_columns_to_drop)
gene_exp_df.to_csv(results_dir/'gene_expression.csv')

cna_columns_to_drop = [col for col in cna_df.columns[2:] if col not in common_patients]
cna_df = cna_df.drop(columns=cna_columns_to_drop)
cna_df.to_csv(results_dir/'cna.csv')

clinical_df = clinical_df[clinical_df['#Patient Identifier'].isin(common_patients)]

# %%
gene_exp_df.shape
# Out:
# (20603, 1982)

# %%
cna_df.shape
# Out:
# (22544, 1982)

# %%
clinical_df.shape
# Out:
# (1980, 24)

# %% [markdown]
# ### 1.3 Checking for missing clinical data

# %%
n = clinical_df.shape[0]

missing_counts = {}  # Dictionary to store missing value counts for each column

for col in clinical_df.columns:
    if col == '#Patient Identifier':
        continue

    n_missing = clinical_df[col].isnull().sum()
    if n_missing>1:  
        missing_counts[col] = n_missing

plt.bar(missing_counts.keys(), missing_counts.values())
plt.xlabel('Columns')
plt.ylabel('Number of missing values')
plt.title('Histogram of missing data')
for i, (col, count) in enumerate(missing_counts.items()):
    percentage = count / n * 100
    plt.text(i, count, f'{percentage:.2f}%', ha='center', va='bottom')
plt.xticks(rotation=90)  
plt.savefig(results_dir/'missing_data_hist.png',dpi=300)
plt.show()

# %%
# Making sure all patients are female
clinical_df['Sex'].value_counts()
# Out:
# Sex
# Female    1980
# Name: count, dtype: int64

# %% [markdown]
# ### 1.4. Selecting clinical features
# For now selecting most of the features, but can fine tune later based on cancer subtypes

# %%
clinical_df.columns
# Out:
# Index(['#Patient Identifier', 'Lymph nodes examined positive',
#        'Nottingham prognostic index', 'Cellularity', 'Chemotherapy', 'Cohort',
#        'ER status measured by IHC', 'HER2 status measured by SNP6',
#        'Hormone Therapy', 'Inferred Menopausal State', 'Sex',
#        'Integrative Cluster', 'Age at Diagnosis', 'Overall Survival (Months)',
#        'Overall Survival Status', 'Pam50 + Claudin-low subtype',
#        '3-Gene classifier subtype', 'Patient's Vital Status',
#        'Primary Tumor Laterality', 'Radio Therapy',
#        'Tumor Other Histologic Subtype', 'Type of Breast Surgery',
#        'Relapse Free Status', 'Relapse Free Status (Months)'],
#       dtype='object')

# %%
# Selecting initial variables
# Excluding 'Relapse Free Status', 'Relapse Free Status (Months)' as they directly indicate whether the patient is L or D
label_cols = ['#Patient Identifier', 'Overall Survival (Months)']
keep_cols = ['Lymph nodes examined positive', 'Nottingham prognostic index', 'Cellularity', 'Chemotherapy','ER status measured by IHC',
            'HER2 status measured by SNP6', 'Hormone Therapy', 'Inferred Menopausal State', 'Integrative Cluster', 'Age at Diagnosis', 
             'Pam50 + Claudin-low subtype', '3-Gene classifier subtype', 'Primary Tumor Laterality', 'Tumor Other Histologic Subtype',  
             'Radio Therapy','Type of Breast Surgery']
columns_to_drop = [col for col in clinical_df.columns if col not in label_cols + keep_cols]
clinical_df = clinical_df.drop(columns=columns_to_drop)
clinical_df.shape
# Out:
# (1980, 18)

# %%
clinical_df.head()
# Out:
#   #Patient Identifier Lymph nodes examined positive  \
# 0             MB-0000                            10
# 1             MB-0002                             0
# 2             MB-0005                             1
# 3             MB-0006                             3
# 4             MB-0008                             8
#
#   Nottingham prognostic index Cellularity Chemotherapy  \
# 0                       6.044         NaN           NO
# 1                        4.02        High           NO
# 2                        4.03        High          YES
# 3                        4.05    Moderate          YES
# 4                        6.08        High          YES
#
#   ER status measured by IHC HER2 status measured by SNP6 Hormone Therapy  \
# 0                   Positve                      NEUTRAL             YES
# 1                   Positve                      NEUTRAL             YES
# 2                   Positve                      NEUTRAL             YES
# 3                   Positve                      NEUTRAL             YES
# 4                   Positve                      NEUTRAL             YES
#
#   Inferred Menopausal State Integrative Cluster Age at Diagnosis  \
# 0                      Post                4ER+            75.65
# 1                       Pre                4ER+            43.19
# 2                       Pre                   3            48.87
# 3                       Pre                   9            47.68
# 4                      Post                   9            76.97
#
#   Overall Survival (Months) Pam50 + Claudin-low subtype  \
# 0                     140.5                 claudin-low
# 1               84.63333333                        LumA
# 2                     163.7                        LumB
# 3               164.9333333                        LumB
# 4               41.36666667                        LumB
#
#   3-Gene classifier subtype Primary Tumor Laterality Radio Therapy  \
# 0                 ER-/HER2-                    Right           YES
# 1     ER+/HER2- High Prolif                    Right           YES
# 2                       NaN                    Right            NO
# 3                       NaN                    Right           YES
# 4     ER+/HER2- High Prolif                    Right           YES
#
#   Tumor Other Histologic Subtype Type of Breast Surgery
# 0                     Ductal/NST             MASTECTOMY
# 1                     Ductal/NST      BREAST CONSERVING
# 2                     Ductal/NST             MASTECTOMY
# 3                          Mixed             MASTECTOMY
# 4                          Mixed             MASTECTOMY

# %% [markdown]
# ### 1.5 Labeling data
# L - 0, D - 1

# %%
clinical_df['event'] = clinical_df['Overall Survival (Months)'].astype(float).apply(lambda x: 0 if x > 60 else 1)
clinical_L_df = clinical_df.loc[clinical_df['Overall Survival (Months)']==0]
clinical_D_df = clinical_df.loc[clinical_df['Overall Survival (Months)']==1]
clinical_df['event'].value_counts()
# Out:
# event
# 0    1489
# 1     491
# Name: count, dtype: int64

# %%
# Because the counts in event categories are substantially different, need decrease the number of L samples
n = 500
clinical_D_df = clinical_df.loc[clinical_df['event'] == 1]
clinical_L_df = pd.DataFrame(clinical_df.loc[clinical_df['event'] == 0].sample(n))
clinical_df = pd.concat([clinical_L_df,clinical_D_df]).reset_index(drop=True)
clinical_df['event'].value_counts()
# Out:
# event
# 0    500
# 1    491
# Name: count, dtype: int64

# %%
clinical_df.set_index('#Patient Identifier', inplace=True)
clinical_df.head()
# Out:
#                     Lymph nodes examined positive Nottingham prognostic index  \
# #Patient Identifier
# MB-5601                                         3                       4.032
# MB-2669                                         0                       3.048
# MB-2618                                         0                       3.032
# MB-5230                                         0                        3.03
# MB-0266                                         0                        1.06
#
#                     Cellularity Chemotherapy ER status measured by IHC  \
# #Patient Identifier
# MB-5601                    High           NO                   Positve
# MB-2669                Moderate           NO                   Positve
# MB-2618                    High           NO                   Positve
# MB-5230                Moderate           NO                   Positve
# MB-0266                Moderate           NO                       NaN
#
#                     HER2 status measured by SNP6 Hormone Therapy  \
# #Patient Identifier
# MB-5601                                  NEUTRAL             YES
# MB-2669                                  NEUTRAL             YES
# MB-2618                                     GAIN              NO
# MB-5230                                  NEUTRAL              NO
# MB-0266                                     GAIN             YES
#
#                     Inferred Menopausal State Integrative Cluster  \
# #Patient Identifier
# MB-5601                                  Post                   3
# MB-2669                                  Post                   6
# MB-2618                                  Post                   1
# MB-5230                                   Pre                   3
# MB-0266                                  Post                   8
#
#                     Age at Diagnosis Overall Survival (Months)  \
# #Patient Identifier
# MB-5601                        61.73                     214.8
# MB-2669                        62.56                      73.7
# MB-2618                        66.22                      89.1
# MB-5230                        48.17                     176.5
# MB-0266                        84.88               90.66666667
#
#                     Pam50 + Claudin-low subtype 3-Gene classifier subtype  \
# #Patient Identifier
# MB-5601                                    LumA      ER+/HER2- Low Prolif
# MB-2669                                    LumA      ER+/HER2- Low Prolif
# MB-2618                                    LumB                       NaN
# MB-5230                                    LumA      ER+/HER2- Low Prolif
# MB-0266                                    LumA                       NaN
#
#                     Primary Tumor Laterality Radio Therapy  \
# #Patient Identifier
# MB-5601                                 Left           YES
# MB-2669                                 Left            NO
# MB-2618                                Right           YES
# MB-5230                                Right           YES
# MB-0266                                 Left           YES
#
#                     Tumor Other Histologic Subtype Type of Breast Surgery  \
# #Patient Identifier
# MB-5601                                 Ductal/NST      BREAST CONSERVING
# MB-2669                                 Ductal/NST             MASTECTOMY
# MB-2618                                 Ductal/NST      BREAST CONSERVING
# MB-5230                                   Mucinous      BREAST CONSERVING
# MB-0266                                      Mixed             MASTECTOMY
#
#                      event
# #Patient Identifier
# MB-5601                  0
# MB-2669                  0
# MB-2618                  0
# MB-5230                  0
# MB-0266                  0

# %% [markdown]
# ### 1.6 Test-val-test splits

# %%
train_val_data, test_data = train_test_split(clinical_df, test_size=0.15, stratify=clinical_df['event'], random_state=42)
train_data, val_data = train_test_split(train_val_data, test_size=0.125, stratify=train_val_data['event'], random_state=42)

# %%
train_data.shape
# Out:
# (736, 18)

# %%
val_data.shape
# Out:
# (106, 18)

# %%
test_data.shape
# Out:
# (149, 18)

# %%
def get_split_group(id_code):
    if id_code in list(train_data.index):
        return 'train'
    elif id_code in val_data.index:
        return 'val'
    elif id_code in test_data.index:
        return 'test'
    else:
        print('Found NaN!')

# %%
clinical_df['group'] = 'Missing'
clinical_df['group'] = [get_split_group(x) for x in list(clinical_df.index)]

# %%
clinical_df.head()
# Out:
#                     Lymph nodes examined positive Nottingham prognostic index  \
# #Patient Identifier
# MB-5601                                         3                       4.032
# MB-2669                                         0                       3.048
# MB-2618                                         0                       3.032
# MB-5230                                         0                        3.03
# MB-0266                                         0                        1.06
#
#                     Cellularity Chemotherapy ER status measured by IHC  \
# #Patient Identifier
# MB-5601                    High           NO                   Positve
# MB-2669                Moderate           NO                   Positve
# MB-2618                    High           NO                   Positve
# MB-5230                Moderate           NO                   Positve
# MB-0266                Moderate           NO                       NaN
#
#                     HER2 status measured by SNP6 Hormone Therapy  \
# #Patient Identifier
# MB-5601                                  NEUTRAL             YES
# MB-2669                                  NEUTRAL             YES
# MB-2618                                     GAIN              NO
# MB-5230                                  NEUTRAL              NO
# MB-0266                                     GAIN             YES
#
#                     Inferred Menopausal State Integrative Cluster  \
# #Patient Identifier
# MB-5601                                  Post                   3
# MB-2669                                  Post                   6
# MB-2618                                  Post                   1
# MB-5230                                   Pre                   3
# MB-0266                                  Post                   8
#
#                     Age at Diagnosis Overall Survival (Months)  \
# #Patient Identifier
# MB-5601                        61.73                     214.8
# MB-2669                        62.56                      73.7
# MB-2618                        66.22                      89.1
# MB-5230                        48.17                     176.5
# MB-0266                        84.88               90.66666667
#
#                     Pam50 + Claudin-low subtype 3-Gene classifier subtype  \
# #Patient Identifier
# MB-5601                                    LumA      ER+/HER2- Low Prolif
# MB-2669                                    LumA      ER+/HER2- Low Prolif
# MB-2618                                    LumB                       NaN
# MB-5230                                    LumA      ER+/HER2- Low Prolif
# MB-0266                                    LumA                       NaN
#
#                     Primary Tumor Laterality Radio Therapy  \
# #Patient Identifier
# MB-5601                                 Left           YES
# MB-2669                                 Left            NO
# MB-2618                                Right           YES
# MB-5230                                Right           YES
# MB-0266                                 Left           YES
#
#                     Tumor Other Histologic Subtype Type of Breast Surgery  \
# #Patient Identifier
# MB-5601                                 Ductal/NST      BREAST CONSERVING
# MB-2669                                 Ductal/NST             MASTECTOMY
# MB-2618                                 Ductal/NST      BREAST CONSERVING
# MB-5230                                   Mucinous      BREAST CONSERVING
# MB-0266                                      Mixed             MASTECTOMY
#
#                      event  group
# #Patient Identifier
# MB-5601                  0  train
# MB-2669                  0  train
# MB-2618                  0  train
# MB-5230                  0    val
# MB-0266                  0  train

# %% [markdown]
# ### 1.7 Input missing numeric data with median value and encode categorical variables

# %%
print('~~ MISSING DATA ~~')
print()
skip = ['project_id', 'days_to_death', 'days_to_last_follow_up']

n = clinical_df.shape[0]

for v in clinical_df.columns:
    if v not in skip:
        n_missing = sum(clinical_df[v].isnull())
        if n_missing > 0:
            print(f'{v}: {n_missing} ({round(n_missing / n * 100, 2)}%)')
# Out:
# ~~ MISSING DATA ~~
#
# Lymph nodes examined positive: 37 (3.73%)
# Cellularity: 22 (2.22%)
# ER status measured by IHC: 18 (1.82%)
# 3-Gene classifier subtype: 117 (11.81%)
# Primary Tumor Laterality: 72 (7.27%)
# Tumor Other Histologic Subtype: 15 (1.51%)
# Type of Breast Surgery: 17 (1.72%)

# %%
def input_missing_values(feature, df):
    train_subset = df.loc[df['group'] == 'train', feature]
    try:
        input_value = train_subset.median()
        print(f'Median "{feature}": {input_value}')
    except TypeError:
        input_value = train_subset.mode().iloc[0]
        print(f'Mode "{feature}": {input_value}')

    df[feature].fillna(input_value, inplace=True)
    
    return df

# %%
clinical_df = input_missing_values(feature='Lymph nodes examined positive', df=clinical_df)
# Out:
# Median "Lymph nodes examined positive": 1.0

# %%
print('~~ MISSING DATA ~~')
print()

n = clinical_df.shape[0]

for v in clinical_df.columns:
    n_missing = sum(clinical_df[v].isnull())
    if n_missing > 0:
        print(f'{v}: {n_missing} ({round(n_missing / n * 100, 2)}%)')
# Out:
# ~~ MISSING DATA ~~
#
# Cellularity: 22 (2.22%)
# ER status measured by IHC: 18 (1.82%)
# 3-Gene classifier subtype: 117 (11.81%)
# Primary Tumor Laterality: 72 (7.27%)
# Tumor Other Histologic Subtype: 15 (1.51%)
# Type of Breast Surgery: 17 (1.72%)

# %%
# Save the df for plotting later
clinical_plot = clinical_df.copy()

# %% [markdown]
# ### Scale continous features

# %%
id_groups = {
    'train': list(clinical_df.loc[clinical_df['group'] == 'train', ].index),
    'val': list(clinical_df.loc[clinical_df['group'] == 'val', ].index),
    'test': list(clinical_df.loc[clinical_df['group'] == 'test', ].index)}

# %%
continuous = ['Age at Diagnosis', 'Nottingham prognostic index']

# %%
def min_max_scale(data, features, groups):
    train = data.loc[data.index.isin(groups['train']), features]

    scaler = MinMaxScaler()
    columns = train.columns
    scaler = scaler.fit(train[columns])
    
    data.loc[data.index.isin(groups['train']), features] = scaler.transform(
        train)
    data.loc[data.index.isin(groups['val']), features] = scaler.transform(
        data.loc[data.index.isin(groups['val']), features])
    data.loc[data.index.isin(groups['test']), features] = scaler.transform(
        data.loc[data.index.isin(groups['test']), features])
    
    return data

# %%
clinical_df = min_max_scale(data=clinical_df, features=continuous, groups = id_groups)
clinical_df.head()
# Out:
#                     Lymph nodes examined positive Nottingham prognostic index  \
# #Patient Identifier
# MB-5601                                         3                    0.565672
# MB-2669                                         0                     0.38209
# MB-2618                                         0                    0.379104
# MB-5230                                         0                    0.378731
# MB-0266                                         0                    0.011194
#
#                     Cellularity Chemotherapy ER status measured by IHC  \
# #Patient Identifier
# MB-5601                    High           NO                   Positve
# MB-2669                Moderate           NO                   Positve
# MB-2618                    High           NO                   Positve
# MB-5230                Moderate           NO                   Positve
# MB-0266                Moderate           NO                       NaN
#
#                     HER2 status measured by SNP6 Hormone Therapy  \
# #Patient Identifier
# MB-5601                                  NEUTRAL             YES
# MB-2669                                  NEUTRAL             YES
# MB-2618                                     GAIN              NO
# MB-5230                                  NEUTRAL              NO
# MB-0266                                     GAIN             YES
#
#                     Inferred Menopausal State Integrative Cluster  \
# #Patient Identifier
# MB-5601                                  Post                   3
# MB-2669                                  Post                   6
# MB-2618                                  Post                   1
# MB-5230                                   Pre                   3
# MB-0266                                  Post                   8
#
#                     Age at Diagnosis Overall Survival (Months)  \
# #Patient Identifier
# MB-5601                     0.535234                     214.8
# MB-2669                     0.546396                      73.7
# MB-2618                     0.595616                      89.1
# MB-5230                     0.352878                     176.5
# MB-0266                     0.846557               90.66666667
#
#                     Pam50 + Claudin-low subtype 3-Gene classifier subtype  \
# #Patient Identifier
# MB-5601                                    LumA      ER+/HER2- Low Prolif
# MB-2669                                    LumA      ER+/HER2- Low Prolif
# MB-2618                                    LumB                       NaN
# MB-5230                                    LumA      ER+/HER2- Low Prolif
# MB-0266                                    LumA                       NaN
#
#                     Primary Tumor Laterality Radio Therapy  \
# #Patient Identifier
# MB-5601                                 Left           YES
# MB-2669                                 Left            NO
# MB-2618                                Right           YES
# MB-5230                                Right           YES
# MB-0266                                 Left           YES
#
#                     Tumor Other Histologic Subtype Type of Breast Surgery  \
# #Patient Identifier
# MB-5601                                 Ductal/NST      BREAST CONSERVING
# MB-2669                                 Ductal/NST             MASTECTOMY
# MB-2618                                 Ductal/NST      BREAST CONSERVING
# MB-5230                                   Mucinous      BREAST CONSERVING
# MB-0266                                      Mixed             MASTECTOMY
#
#                      event  group
# #Patient Identifier
# MB-5601                  0  train
# MB-2669                  0  train
# MB-2618                  0  train
# MB-5230                  0    val
# MB-0266                  0  train

# %% [markdown]
# ### Encode categorical variables

# %%
clinical_df = clinical_df.drop(columns=['Overall Survival (Months)'])

# %%
clinical_df.columns
# Out:
# Index(['Lymph nodes examined positive', 'Nottingham prognostic index',
#        'Cellularity', 'Chemotherapy', 'ER status measured by IHC',
#        'HER2 status measured by SNP6', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster', 'Age at Diagnosis',
#        'Pam50 + Claudin-low subtype', '3-Gene classifier subtype',
#        'Primary Tumor Laterality', 'Radio Therapy',
#        'Tumor Other Histologic Subtype', 'Type of Breast Surgery', 'event',
#        'group'],
#       dtype='object')

# %%
skip = ['event', 'group', 'Lymph nodes examined positive']

# %%
categorical = [col for col in clinical_df.columns if col not in skip + continuous]

# %%
split_groups = ['train', 'val', 'test']

label_encoders = {}
for feature in categorical:
    clinical_df[feature] = clinical_df[feature].astype(str)
    label_encoders[feature] = LabelEncoder()
    label_encoders[feature].fit(
        clinical_df.loc[clinical_df['group'] == 'train', feature])

for group in split_groups:
    for feature in categorical:
        clinical_df.loc[
            clinical_df['group'] == group, feature] = label_encoders[feature].transform(
            clinical_df.loc[clinical_df['group'] == group, feature])
# Out:
# Cellularity
# Chemotherapy
# ER status measured by IHC
# HER2 status measured by SNP6
# Hormone Therapy
# Inferred Menopausal State
# Integrative Cluster
# Pam50 + Claudin-low subtype
# 3-Gene classifier subtype
# Primary Tumor Laterality
# Radio Therapy
# Tumor Other Histologic Subtype
# Type of Breast Surgery
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/3d_dist/lib/python3.8/site-packages/sklearn/utils/_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File ~/anaconda3/envs/3d_dist/lib/python3.8/site-packages/sklearn/utils/_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~/anaconda3/envs/3d_dist/lib/python3.8/site-packages/sklearn/utils/_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~/anaconda3/envs/3d_dist/lib/python3.8/site-packages/sklearn/utils/_encode.py:159, in _nandict.__missing__(self, key)
#     158     return self.nan_value
# --> 159 raise KeyError(key)
#
# KeyError: 'GAIN'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 14
#      11 for group in split_groups:
#      12     for feature in categorical:
#      13         clinical_df.loc[
# ---> 14             clinical_df['group'] == group, feature] = label_encoders[feature].transform(
#      15             clinical_df.loc[clinical_df['group'] == group, feature])
#
# File ~/anaconda3/envs/3d_dist/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:137, in LabelEncoder.transform(self, y)
#     134 if _num_samples(y) == 0:
#     135     return np.array([])
# --> 137 return _encode(y, uniques=self.classes_)
#
# File ~/anaconda3/envs/3d_dist/lib/python3.8/site-packages/sklearn/utils/_encode.py:227, in _encode(values, uniques, check_unknown)
#     225         return _map_to_integer(values, uniques)
#     226     except KeyError as e:
# --> 227         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     228 else:
#     229     if check_unknown:
#
# ValueError: y contains previously unseen labels: 'GAIN'

# %%
clinical_df.head()
# Out:
#                     Lymph nodes examined positive Nottingham prognostic index  \
# #Patient Identifier
# MB-4928                                         1                     0.76015
# MB-4876                                         0                    0.386466
# MB-5332                                         1                    0.570677
# MB-4744                                         2                    0.757895
# MB-5531                                         0                    0.381579
#
#                     Cellularity Chemotherapy ER status measured by IHC  \
# #Patient Identifier
# MB-4928                       2            0                         1
# MB-4876                       1            0                         1
# MB-5332                       0            0                         1
# MB-4744                       0            0                         1
# MB-5531                       0            0                         0
#
#                     HER2 status measured by SNP6 Hormone Therapy  \
# #Patient Identifier
# MB-4928                                        0               1
# MB-4876                                        2               0
# MB-5332                                        0               1
# MB-4744                                        2               1
# MB-5531                                        2               0
#
#                     Inferred Menopausal State Integrative Cluster  \
# #Patient Identifier
# MB-4928                                     0                   6
# MB-4876                                     1                   4
# MB-5332                                     0                   6
# MB-4744                                     0                   9
# MB-5531                                     0                   1
#
#                     Age at Diagnosis Pam50 + Claudin-low subtype  \
# #Patient Identifier
# MB-4928                      0.71638                           1
# MB-4876                     0.275955                           6
# MB-5332                      0.63206                           1
# MB-4744                     0.568585                           3
# MB-5531                     0.600188                           6
#
#                     3-Gene classifier subtype Primary Tumor Laterality  \
# #Patient Identifier
# MB-4928                                     4                        1
# MB-4876                                     2                        0
# MB-5332                                     0                        0
# MB-4744                                     4                        1
# MB-5531                                     2                        1
#
#                     Radio Therapy Tumor Other Histologic Subtype  \
# #Patient Identifier
# MB-4928                         0                              0
# MB-4876                         1                              1
# MB-5332                         0                              0
# MB-4744                         1                              0
# MB-5531                         1                              0
#
#                     Type of Breast Surgery  event  group
# #Patient Identifier
# MB-4928                                  1      0  train
# MB-4876                                  0      0  train
# MB-5332                                  1      0  train
# MB-4744                                  0      0    val
# MB-5531                                  0      0  train

# %% [markdown]
# ### 1.8 Select top important features

# %%
X = clinical_df.drop(columns=['event', 'group']) 
y = clinical_df['event'] 

rf_model = RandomForestClassifier()
rf_model.fit(X, y)

feature_importance = rf_model.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
plt.savefig(results_dir/'clinical_features_importance.png')
plt.show()

# %%
threshold = 0.05
selected_features = X.columns[feature_importance >= threshold]
selected_features
# Out:
# Index(['Lymph nodes examined positive', 'Nottingham prognostic index',
#        'Integrative Cluster', 'Age at Diagnosis',
#        'Pam50 + Claudin-low subtype'],
#       dtype='object')

# %%
skip = ['event', 'group']
all_cols = [col for col in clinical_df.columns if col in list(selected_features) + skip]
clinical_df = clinical_df[all_cols]
clinical_df.head()
# Out:
#                     Lymph nodes examined positive Nottingham prognostic index  \
# #Patient Identifier
# MB-5460                                       1.0                    0.561567
# MB-0452                                         0                    0.568284
# MB-0351                                       1.0                         0.0
# MB-0543                                       1.0                    0.756343
# MB-5013                                         1                    0.567164
#
#                     Integrative Cluster Age at Diagnosis  \
# #Patient Identifier
# MB-5460                              10         0.452663
# MB-0452                              10         0.437063
# MB-0351                               3         0.640129
# MB-0543                               0         0.322351
# MB-5013                               3         0.627084
#
#                     Pam50 + Claudin-low subtype  event  group
# #Patient Identifier
# MB-5460                                       0      0  train
# MB-0452                                       3      0  train
# MB-0351                                       3      0  train
# MB-0543                                       0      0    val
# MB-5013                                       2      0  train

# %%
clinical_df.to_csv(results_dir/'preprocessed_clinical_data.csv')

# %% [markdown]
# ### Exploring feature distributions

# %%
def plot_histogram(dfs, column_name, file_path, dpi=300, fontsize=8):
    fig, ax = plt.subplots()
    
    for df, label in dfs:
        value_counts = df[column_name].value_counts()
        ax.bar(value_counts.index, value_counts.values, label=label, alpha=0.5)
        
    ax.set_xlabel(column_name)
    ax.set_ylabel('Number of Patients')
    ax.set_title(f'Histogram of {column_name}')
    ax.legend()  
    
    ax.tick_params(axis='x', labelsize=fontsize)  
    
    plt.savefig(file_path, dpi=dpi) 
    plt.show()

# %%
plot_histogram([(clinical_plot, 'All Patients'), (clinical_L_df, 'L Patients'), (clinical_D_df, 'D Patients')],
               'Integrative Cluster', 
               results_dir / 'integrative_cluster_hist_combined.png')

# %%
plot_histogram([(clinical_plot, 'All Patients'), (clinical_L_df, 'L Patients'), (clinical_D_df, 'D Patients')],
               'Pam50 + Claudin-low subtype', 
               results_dir / 'Pam50_sybtype_hist_combined.png')

# %%
fig, ax = plt.subplots()
column = 'Overall Survival (Months)'

clinical_plot[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='All Patients')
clinical_L_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='L Patients')
clinical_D_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='D Patients')

ax.set_title(f'Histogram of {column} in Years')
ax.set_xlabel(column)
ax.set_ylabel('Number of Patients')
ax.legend()

plt.savefig(results_dir / 'survival_hist_combined.png', dpi=300)

plt.show()

# %%
fig, ax = plt.subplots()
column = 'Age at Diagnosis'

clinical_plot[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='All Patients')
clinical_L_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='L Patients')
clinical_D_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='D Patients')

ax.set_title(f'Histogram of {column} in Years')
ax.set_xlabel(column)
ax.set_ylabel('Number of Patients')
ax.legend()

plt.savefig(results_dir / 'age_hist_combined.png', dpi=300)

plt.show()

# %%
fig, ax = plt.subplots()
column = 'Lymph nodes examined positive'

clinical_plot[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='All Patients')
clinical_L_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='L Patients')
clinical_D_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='D Patients')

ax.set_title(f'Histogram of {column} in Years')
ax.set_xlabel(column)
ax.set_ylabel('Number of Patients')
ax.legend()

plt.savefig(results_dir / 'lymph_nodes_hist_combined.png', dpi=300)

plt.show()

# %%
fig, ax = plt.subplots()
column = 'Nottingham prognostic index'

clinical_plot[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='All Patients')
clinical_L_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='L Patients')
clinical_D_df[column].astype(float).plot(kind='hist', ax=ax, alpha=0.5, label='D Patients')

ax.set_title(f'Histogram of {column} in Years')
ax.set_xlabel(column)
ax.set_ylabel('Number of Patients')
ax.legend()

plt.savefig(results_dir / 'NPI_hist_combined.png', dpi=300)

plt.show()

# %%
#Future work, fixing imbalance with SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
